# %%
# Importing Libs
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [12, 7]

# %%
df = pd.read_csv('../enc_devs_py.csv')

# %%
from IPython.core.display import HTML as Center

Center(""" <style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style> """)
# Out:
#  <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# # Sueldos
# - Sueldos percibidos por los devs que contestaron las preguntas.

# %% [markdown]
# ### Segun GENERO

# %%
by_genere = df.groupby('Género')

# %%
df['Género'].value_counts()
# Out:
# Hombre                   279
# Mujer                     49
# Prefiero no compartir      3
# Otros                      2
# Género                     1
# Name: Género, dtype: int64

# %%
df['Género'].value_counts(normalize=True)
# Out:
# Hombre                   0.835329
# Mujer                    0.146707
# Prefiero no compartir    0.008982
# Otros                    0.005988
# Género                   0.002994
# Name: Género, dtype: float64

# %%
# Grupos disponibles.
df['Género'].value_counts().keys()
# Out:
# Index(['Hombre', 'Mujer', 'Prefiero no compartir', 'Otros', 'Género'], dtype='object')

# %%
df.columns
# Out:
# Index(['Marca temporal', 'Modalidad', 'Trabajo', 'Tipo de trabajo', 'DevOps',
#        'Codificar por trabajo', 'Experiencia en TI',
#        'Experiencia en codificación ',
#        'Primera línea de código en una máquina', 'Educación',
#        'Carreras o especialidades', 'Importancia educación formal', 'Género',
#        'Edad actual ', 'Salario mensual',
#        'Programación, scripting y lenguajes de marcado',
#        'Librerías o web frameworks',
#        'Otras frameworks, librerías y herramientas', 'Base de datos',
#        'Plataformas', 'Lenguaje favorito', 'Lenguaje más odiado',
#        'Framework favorito', 'Framework más odiado', 'Herramientas'],
#       dtype='object')

# %% [markdown]
# ### MIXTO

# %%
salario_hombres = df.groupby('Género').get_group('Hombre')['Salario mensual'].value_counts()

# %%
salario_mujeres = df.groupby('Género').get_group('Mujer')['Salario mensual'].value_counts()

# %%
print('keys hombres', len(salario_hombres.keys()))
print('keys mujers', len(salario_mujeres.keys()))
# Out:
# keys hombres 13
# keys mujers 9

# %%
sueldos =[]
for i in salario_hombres.keys():
    sueldos.append([i,salario_mujeres.get(i,0),salario_hombres.get(i, 0)])

# %%
df_sueldos = pd.DataFrame(sueldos, columns = ['rango', 'mujeres', 'hombres']).set_index('rango')

# %%
df_sueldos
# Out:
#                                           mujeres  hombres
# rango
# Entre 5.000.000 a 7.000.000 gs                 12       48
# Entre 7.000.000 a 9.000.000 gs                  8       41
# Entre 9.000.000 a 12.000.000 gs                 7       37
# Entre 3.500.000 a 5.000.000 gs                  7       37
# Entre 2.192.839 gs a 3.500.000 gs               7       31
# Entre 12.000.000 a 15.000.000 gs                3       23
# Menos del salario mínimo ( 2.192.839 gs)        0       13
# Entre 15.000.000 a 18.000.000 gs                0       13
# Más de 27.000.000 gs                            2       13
# Entre 21.000.000 a 24.000.000 gs                0        7
# Salario mínimo 2.192.839 gs                     2        6
# Entre 18.000.000 a 21.000.000 gs                1        6
# Entre 24.000.000 a 27.000.000 gs                0        4

# %%
df_sueldos.hombres.plot(kind='barh', 
                        title='Sueldos Hombres', 
                        xlabel='Rango', 
                        ylabel='Millones',
                        color='blue',
                        width = 0.2)
df_sueldos.mujeres.plot(kind='barh', 
                        title='Sueldos Mujeres', 
                        xlabel='Rango', 
                        ylabel='Millones',
                        color='pink',
                        width = 0.2)
plt.legend()

# %% [markdown]
# ### SOLO HOMBRES

# %%
df.groupby('Género').get_group('Hombre')['Salario mensual'].value_counts()
# Out:
# Entre 5.000.000 a 7.000.000 gs              48
# Entre 7.000.000 a 9.000.000 gs              41
# Entre 9.000.000 a 12.000.000 gs             37
# Entre 3.500.000 a 5.000.000 gs              37
# Entre 2.192.839 gs a 3.500.000 gs           31
# Entre 12.000.000 a 15.000.000 gs            23
# Menos del salario mínimo ( 2.192.839 gs)    13
# Entre 15.000.000 a 18.000.000 gs            13
# Más de 27.000.000 gs                        13
# Entre 21.000.000 a 24.000.000 gs             7
# Salario mínimo 2.192.839 gs                  6
# Entre 18.000.000 a 21.000.000 gs             6
# Entre 24.000.000 a 27.000.000 gs             4
# Name: Salario mensual, dtype: int64

# %%
df.groupby('Género').get_group('Hombre')['Salario mensual'].value_counts(normalize=True)
# Out:
# Entre 5.000.000 a 7.000.000 gs              0.172043
# Entre 7.000.000 a 9.000.000 gs              0.146953
# Entre 9.000.000 a 12.000.000 gs             0.132616
# Entre 3.500.000 a 5.000.000 gs              0.132616
# Entre 2.192.839 gs a 3.500.000 gs           0.111111
# Entre 12.000.000 a 15.000.000 gs            0.082437
# Menos del salario mínimo ( 2.192.839 gs)    0.046595
# Entre 15.000.000 a 18.000.000 gs            0.046595
# Más de 27.000.000 gs                        0.046595
# Entre 21.000.000 a 24.000.000 gs            0.025090
# Salario mínimo 2.192.839 gs                 0.021505
# Entre 18.000.000 a 21.000.000 gs            0.021505
# Entre 24.000.000 a 27.000.000 gs            0.014337
# Name: Salario mensual, dtype: float64

# %%
df.groupby('Género').get_group('Hombre')['Salario mensual'].value_counts().plot(kind='barh',
                                                                               title='Sueldo solo Hombres',
                                                                               color='blue')
# Out:
# <AxesSubplot:title={'center':'Sueldo solo Hombres'}>

# %% [markdown]
# ### SOLO MUJERES

# %%
df.groupby('Género').get_group('Mujer')['Salario mensual'].value_counts()
# Out:
# Entre 5.000.000 a 7.000.000 gs       12
# Entre 7.000.000 a 9.000.000 gs        8
# Entre 9.000.000 a 12.000.000 gs       7
# Entre 2.192.839 gs a 3.500.000 gs     7
# Entre 3.500.000 a 5.000.000 gs        7
# Entre 12.000.000 a 15.000.000 gs      3
# Salario mínimo 2.192.839 gs           2
# Más de 27.000.000 gs                  2
# Entre 18.000.000 a 21.000.000 gs      1
# Name: Salario mensual, dtype: int64

# %%
df.groupby('Género').get_group('Mujer')['Salario mensual'].value_counts(normalize=True)
# Out:
# Entre 5.000.000 a 7.000.000 gs       0.244898
# Entre 7.000.000 a 9.000.000 gs       0.163265
# Entre 9.000.000 a 12.000.000 gs      0.142857
# Entre 2.192.839 gs a 3.500.000 gs    0.142857
# Entre 3.500.000 a 5.000.000 gs       0.142857
# Entre 12.000.000 a 15.000.000 gs     0.061224
# Salario mínimo 2.192.839 gs          0.040816
# Más de 27.000.000 gs                 0.040816
# Entre 18.000.000 a 21.000.000 gs     0.020408
# Name: Salario mensual, dtype: float64

# %%
df.groupby('Género').get_group('Mujer')['Salario mensual'].value_counts().plot(kind='barh',
                                                                              title='SALARIO SOLO MUJERES',
                                                                              color='pink')
# Out:
# <AxesSubplot:title={'center':'SALARIO SOLO MUJERES'}>

# %% [markdown]
# ### Segun ORIGEN DEL TRABAJO

# %%
df['Trabajo'].value_counts(normalize=True)
# Out:
# Nacional (Paraguay)    0.757310
# Ambas                  0.128655
# Internacional          0.114035
# Name: Trabajo, dtype: float64

# %%
df['Trabajo'].value_counts()
# Out:
# Nacional (Paraguay)    259
# Ambas                   44
# Internacional           39
# Name: Trabajo, dtype: int64

# %%
df['Trabajo'].value_counts(normalize=True).plot(kind='pie', title='Origen del trabajo.',ylabel='')
# Out:
# /home/torrezmn/Documents/DS_ENV/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:title={'center':'Origen del trabajo.'}>

# %%
orig_trabajo = df.groupby('Trabajo')

# %% [markdown]
# #### NACIONAL

# %%
orig_trabajo.get_group('Nacional (Paraguay)')['Salario mensual'].value_counts()
# Out:
# Entre 5.000.000 a 7.000.000 gs              49
# Entre 7.000.000 a 9.000.000 gs              42
# Entre 3.500.000 a 5.000.000 gs              41
# Entre 9.000.000 a 12.000.000 gs             40
# Entre 2.192.839 gs a 3.500.000 gs           35
# Entre 12.000.000 a 15.000.000 gs            19
# Menos del salario mínimo ( 2.192.839 gs)    11
# Entre 15.000.000 a 18.000.000 gs             7
# Salario mínimo 2.192.839 gs                  6
# Entre 21.000.000 a 24.000.000 gs             4
# Entre 18.000.000 a 21.000.000 gs             3
# Entre 24.000.000 a 27.000.000 gs             1
# Más de 27.000.000 gs                         1
# Name: Salario mensual, dtype: int64

# %%
orig_trabajo.get_group('Nacional (Paraguay)')['Salario mensual'].value_counts().plot(
    kind='barh',
    title='Salario de Nivel Nacional',
    ylabel='')
# Out:
# <AxesSubplot:title={'center':'Salario de Nivel Nacional'}>

# %% [markdown]
# #### Internacional

# %%
orig_trabajo.get_group('Internacional')['Salario mensual'].value_counts()
# Out:
# Más de 27.000.000 gs                        12
# Entre 5.000.000 a 7.000.000 gs               8
# Entre 18.000.000 a 21.000.000 gs             4
# Entre 15.000.000 a 18.000.000 gs             3
# Entre 7.000.000 a 9.000.000 gs               3
# Entre 24.000.000 a 27.000.000 gs             2
# Entre 9.000.000 a 12.000.000 gs              2
# Entre 21.000.000 a 24.000.000 gs             1
# Entre 12.000.000 a 15.000.000 gs             1
# Menos del salario mínimo ( 2.192.839 gs)     1
# Entre 2.192.839 gs a 3.500.000 gs            1
# Entre 3.500.000 a 5.000.000 gs               1
# Name: Salario mensual, dtype: int64

# %%
orig_trabajo.get_group('Internacional')['Salario mensual'].value_counts(normalize=True)
# Out:
# Más de 27.000.000 gs                        0.307692
# Entre 5.000.000 a 7.000.000 gs              0.205128
# Entre 18.000.000 a 21.000.000 gs            0.102564
# Entre 15.000.000 a 18.000.000 gs            0.076923
# Entre 7.000.000 a 9.000.000 gs              0.076923
# Entre 24.000.000 a 27.000.000 gs            0.051282
# Entre 9.000.000 a 12.000.000 gs             0.051282
# Entre 21.000.000 a 24.000.000 gs            0.025641
# Entre 12.000.000 a 15.000.000 gs            0.025641
# Menos del salario mínimo ( 2.192.839 gs)    0.025641
# Entre 2.192.839 gs a 3.500.000 gs           0.025641
# Entre 3.500.000 a 5.000.000 gs              0.025641
# Name: Salario mensual, dtype: float64

# %%
orig_trabajo.get_group('Internacional')['Salario mensual'].value_counts().plot(
    kind='barh',
    title='SALARIOS INTERNACIONALES',
    ylabel='')
# Out:
# <AxesSubplot:title={'center':'SALARIOS INTERNACIONALES'}>

# %% [markdown]
# #### Ambas

# %%
orig_trabajo.get_group('Ambas')['Salario mensual'].value_counts()
# Out:
# Entre 12.000.000 a 15.000.000 gs            8
# Entre 7.000.000 a 9.000.000 gs              5
# Entre 5.000.000 a 7.000.000 gs              5
# Entre 3.500.000 a 5.000.000 gs              4
# Entre 15.000.000 a 18.000.000 gs            4
# Más de 27.000.000 gs                        4
# Entre 9.000.000 a 12.000.000 gs             3
# Entre 2.192.839 gs a 3.500.000 gs           3
# Entre 21.000.000 a 24.000.000 gs            2
# Salario mínimo 2.192.839 gs                 2
# Entre 18.000.000 a 21.000.000 gs            2
# Menos del salario mínimo ( 2.192.839 gs)    1
# Entre 24.000.000 a 27.000.000 gs            1
# Name: Salario mensual, dtype: int64

# %%
orig_trabajo.get_group('Ambas')['Salario mensual'].value_counts(normalize=True)
# Out:
# Entre 12.000.000 a 15.000.000 gs            0.181818
# Entre 7.000.000 a 9.000.000 gs              0.113636
# Entre 5.000.000 a 7.000.000 gs              0.113636
# Entre 3.500.000 a 5.000.000 gs              0.090909
# Entre 15.000.000 a 18.000.000 gs            0.090909
# Más de 27.000.000 gs                        0.090909
# Entre 9.000.000 a 12.000.000 gs             0.068182
# Entre 2.192.839 gs a 3.500.000 gs           0.068182
# Entre 21.000.000 a 24.000.000 gs            0.045455
# Salario mínimo 2.192.839 gs                 0.045455
# Entre 18.000.000 a 21.000.000 gs            0.045455
# Menos del salario mínimo ( 2.192.839 gs)    0.022727
# Entre 24.000.000 a 27.000.000 gs            0.022727
# Name: Salario mensual, dtype: float64

# %%
orig_trabajo.get_group('Ambas')['Salario mensual'].value_counts().plot(kind='barh', title='Salarios tipo Mixto',ylabel='')
# Out:
# <AxesSubplot:title={'center':'Salarios tipo Mixto'}>

# %% [markdown]
# ### Segun MODALIDAD

# %%
df['Modalidad'].value_counts()
# Out:
# Remoto                       145
# Hibrído                      110
# Presencial                    78
# Ninguna de las anteriores      9
# Name: Modalidad, dtype: int64

# %%
salario_modalidad = df.groupby('Modalidad')

# %% [markdown]
# #### REMOTO

# %%
salario_modalidad.get_group('Remoto')['Salario mensual'].value_counts()
# Out:
# Entre 5.000.000 a 7.000.000 gs              27
# Entre 3.500.000 a 5.000.000 gs              22
# Entre 7.000.000 a 9.000.000 gs              19
# Entre 9.000.000 a 12.000.000 gs             18
# Más de 27.000.000 gs                        15
# Entre 2.192.839 gs a 3.500.000 gs           11
# Entre 12.000.000 a 15.000.000 gs             7
# Menos del salario mínimo ( 2.192.839 gs)     7
# Entre 15.000.000 a 18.000.000 gs             6
# Entre 18.000.000 a 21.000.000 gs             5
# Entre 21.000.000 a 24.000.000 gs             3
# Entre 24.000.000 a 27.000.000 gs             3
# Salario mínimo 2.192.839 gs                  2
# Name: Salario mensual, dtype: int64

# %%
salario_modalidad.get_group('Remoto')['Salario mensual'].value_counts(normalize=True)
# Out:
# Entre 5.000.000 a 7.000.000 gs              0.186207
# Entre 3.500.000 a 5.000.000 gs              0.151724
# Entre 7.000.000 a 9.000.000 gs              0.131034
# Entre 9.000.000 a 12.000.000 gs             0.124138
# Más de 27.000.000 gs                        0.103448
# Entre 2.192.839 gs a 3.500.000 gs           0.075862
# Entre 12.000.000 a 15.000.000 gs            0.048276
# Menos del salario mínimo ( 2.192.839 gs)    0.048276
# Entre 15.000.000 a 18.000.000 gs            0.041379
# Entre 18.000.000 a 21.000.000 gs            0.034483
# Entre 21.000.000 a 24.000.000 gs            0.020690
# Entre 24.000.000 a 27.000.000 gs            0.020690
# Salario mínimo 2.192.839 gs                 0.013793
# Name: Salario mensual, dtype: float64

# %%
salario_modalidad.get_group('Remoto')['Salario mensual'].value_counts().plot(
    kind='barh',
    title='Salarios Modalidad Remota',
    ylabel='')
# Out:
# <AxesSubplot:title={'center':'Salarios Modalidad Remota'}>

# %% [markdown]
# #### HIBRIDO

# %%
salario_modalidad.get_group('Hibrído')['Salario mensual'].value_counts()
# Out:
# Entre 5.000.000 a 7.000.000 gs              20
# Entre 12.000.000 a 15.000.000 gs            16
# Entre 9.000.000 a 12.000.000 gs             15
# Entre 7.000.000 a 9.000.000 gs              15
# Entre 3.500.000 a 5.000.000 gs              14
# Entre 2.192.839 gs a 3.500.000 gs           11
# Entre 15.000.000 a 18.000.000 gs             7
# Entre 21.000.000 a 24.000.000 gs             3
# Entre 18.000.000 a 21.000.000 gs             3
# Salario mínimo 2.192.839 gs                  2
# Menos del salario mínimo ( 2.192.839 gs)     2
# Entre 24.000.000 a 27.000.000 gs             1
# Más de 27.000.000 gs                         1
# Name: Salario mensual, dtype: int64

# %%
salario_modalidad.get_group('Hibrído')['Salario mensual'].value_counts(normalize=True)
# Out:
# Entre 5.000.000 a 7.000.000 gs              0.181818
# Entre 12.000.000 a 15.000.000 gs            0.145455
# Entre 9.000.000 a 12.000.000 gs             0.136364
# Entre 7.000.000 a 9.000.000 gs              0.136364
# Entre 3.500.000 a 5.000.000 gs              0.127273
# Entre 2.192.839 gs a 3.500.000 gs           0.100000
# Entre 15.000.000 a 18.000.000 gs            0.063636
# Entre 21.000.000 a 24.000.000 gs            0.027273
# Entre 18.000.000 a 21.000.000 gs            0.027273
# Salario mínimo 2.192.839 gs                 0.018182
# Menos del salario mínimo ( 2.192.839 gs)    0.018182
# Entre 24.000.000 a 27.000.000 gs            0.009091
# Más de 27.000.000 gs                        0.009091
# Name: Salario mensual, dtype: float64

# %%
salario_modalidad.get_group('Hibrído')['Salario mensual'].value_counts().plot(
    kind='barh',
    title='Salarios Modalidad Hibrida')
# Out:
# <AxesSubplot:title={'center':'Salarios Modalidad Hibrida'}>

# %% [markdown]
# #### PRESENCIAL

# %%
salario_modalidad.get_group('Presencial')['Salario mensual'].value_counts()
# Out:
# Entre 7.000.000 a 9.000.000 gs       16
# Entre 2.192.839 gs a 3.500.000 gs    15
# Entre 5.000.000 a 7.000.000 gs       14
# Entre 9.000.000 a 12.000.000 gs      12
# Entre 3.500.000 a 5.000.000 gs        9
# Entre 12.000.000 a 15.000.000 gs      5
# Salario mínimo 2.192.839 gs           4
# Entre 15.000.000 a 18.000.000 gs      1
# Entre 18.000.000 a 21.000.000 gs      1
# Entre 21.000.000 a 24.000.000 gs      1
# Name: Salario mensual, dtype: int64

# %%
salario_modalidad.get_group('Presencial')['Salario mensual'].value_counts(normalize=True)
# Out:
# Entre 7.000.000 a 9.000.000 gs       0.205128
# Entre 2.192.839 gs a 3.500.000 gs    0.192308
# Entre 5.000.000 a 7.000.000 gs       0.179487
# Entre 9.000.000 a 12.000.000 gs      0.153846
# Entre 3.500.000 a 5.000.000 gs       0.115385
# Entre 12.000.000 a 15.000.000 gs     0.064103
# Salario mínimo 2.192.839 gs          0.051282
# Entre 15.000.000 a 18.000.000 gs     0.012821
# Entre 18.000.000 a 21.000.000 gs     0.012821
# Entre 21.000.000 a 24.000.000 gs     0.012821
# Name: Salario mensual, dtype: float64

# %%
salario_modalidad.get_group('Presencial')['Salario mensual'].value_counts().plot(
    kind='barh',
    title='Salarios Modalidad Presencial')
# Out:
# <AxesSubplot:title={'center':'Salarios Modalidad Presencial'}>

# %% [markdown]
# #### Ninguna de las anteriores

# %%
salario_modalidad.get_group('Ninguna de las anteriores')['Salario mensual'].value_counts()
# Out:
# Menos del salario mínimo ( 2.192.839 gs)    4
# Entre 2.192.839 gs a 3.500.000 gs           2
# Entre 5.000.000 a 7.000.000 gs              1
# Más de 27.000.000 gs                        1
# Entre 3.500.000 a 5.000.000 gs              1
# Name: Salario mensual, dtype: int64

# %%
salario_modalidad.get_group('Ninguna de las anteriores')['Salario mensual'].value_counts(normalize=True)
# Out:
# Menos del salario mínimo ( 2.192.839 gs)    0.444444
# Entre 2.192.839 gs a 3.500.000 gs           0.222222
# Entre 5.000.000 a 7.000.000 gs              0.111111
# Más de 27.000.000 gs                        0.111111
# Entre 3.500.000 a 5.000.000 gs              0.111111
# Name: Salario mensual, dtype: float64

# %%
salario_modalidad.get_group('Ninguna de las anteriores')['Salario mensual'].value_counts().plot(
    kind='barh',
    title='Salario regular (ninguna de las anteriores',
    ylabel='')
# Out:
# <AxesSubplot:title={'center':'Salario regular (ninguna de las anteriores'}>

# %% [markdown]
# ### Experiencia en TI

# %%
experiencia =  [i for i in df['Experiencia en TI'].value_counts().keys()]
experiencia
# Out:
# ['5 a 9 años',
#  'Menos de 5 años',
#  '10 a 14 años',
#  '15 a 19 años',
#  '20 a 24 años',
#  '25 a 29 años',
#  '30 a 34 años',
#  '35 a 39 años',
#  'más de 50 años',
#  '45 a 49 años']

# %%
df['Experiencia en TI'].value_counts()
# Out:
# 5 a 9 años         124
# Menos de 5 años     94
# 10 a 14 años        82
# 15 a 19 años        20
# 20 a 24 años         9
# 25 a 29 años         5
# 30 a 34 años         4
# 35 a 39 años         2
# más de 50 años       1
# 45 a 49 años         1
# Name: Experiencia en TI, dtype: int64

# %%
df['Experiencia en TI'].value_counts(normalize=True)
# Out:
# 5 a 9 años         0.362573
# Menos de 5 años    0.274854
# 10 a 14 años       0.239766
# 15 a 19 años       0.058480
# 20 a 24 años       0.026316
# 25 a 29 años       0.014620
# 30 a 34 años       0.011696
# 35 a 39 años       0.005848
# más de 50 años     0.002924
# 45 a 49 años       0.002924
# Name: Experiencia en TI, dtype: float64

# %%
años_exp = df.groupby('Experiencia en TI')

# %%
años_exp.get_group(experiencia[0])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[0])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 5 a 9 años'}>

# %%
años_exp.get_group(experiencia[1])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[1])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario Menos de 5 años'}>

# %%
años_exp.get_group(experiencia[2])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[2])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 10 a 14 años'}>

# %%
años_exp.get_group(experiencia[3])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[3])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 15 a 19 años'}>

# %%
años_exp.get_group(experiencia[4])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[4])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 20 a 24 años'}>

# %%
años_exp.get_group(experiencia[5])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[5])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 25 a 29 años'}>

# %%
años_exp.get_group(experiencia[6])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[6])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 30 a 34 años'}>

# %%
años_exp.get_group(experiencia[7])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[7])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 35 a 39 años'}>

# %%
años_exp.get_group(experiencia[8])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[8])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario más de 50 años'}>

# %%
años_exp.get_group(experiencia[9])['Salario mensual'].value_counts().plot(
        kind='barh',
        title='SAlario {0}'.format(experiencia[9])
        )
# Out:
# <AxesSubplot:title={'center':'SAlario 45 a 49 años'}>

# %%
df.columns
# Out:
# Index(['Marca temporal', 'Modalidad', 'Trabajo', 'Tipo de trabajo', 'DevOps',
#        'Codificar por trabajo', 'Experiencia en TI',
#        'Experiencia en codificación ',
#        'Primera línea de código en una máquina', 'Educación',
#        'Carreras o especialidades', 'Importancia educación formal', 'Género',
#        'Edad actual ', 'Salario mensual',
#        'Programación, scripting y lenguajes de marcado',
#        'Librerías o web frameworks',
#        'Otras frameworks, librerías y herramientas', 'Base de datos',
#        'Plataformas', 'Lenguaje favorito', 'Lenguaje más odiado',
#        'Framework favorito', 'Framework más odiado', 'Herramientas'],
#       dtype='object')
