# %%
# Importing Libs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# from Toolkit import tool

# My Tools

# %matplotlib inline

# %%
# Reseting figure size params.
plt.rcParams["figure.figsize"] = [12, 7]

# Setting seaborn as default plotting lib.
sns.set()

# %%
sns.set_palette("pastel")

# %%
df = pd.read_csv("./central_df.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'marca_temporal', 'lugar_residencia',
#        'lugar_residencia_py', 'estado_calles', 'problema_baches',
#        'estimacion_cantidad', 'tipo_camino', 'tiempo_reparaciones',
#        'como_denunciar', 'acceso_informacion', 'sufrio_accidentes',
#        'frecuencia_mantenimiento', 'denunciaria_baches', 'util_conocer',
#        'respuesta_gubernamental', 'regularidad_reparaciones'],
#       dtype='object')

# %% [markdown]
# # estado_calles

# %%
df["estado_calles"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='estado_calles'>

# %% [markdown]
# # problema_baches

# %%
df["problema_baches"].value_counts(normalize=True).plot(
    kind="pie",
    explode=[0,.1,.2],
    xlabel='',
    ylabel='',
    legend=True,
    title='Tiene un problema de baches?'
)
# Out:
# <AxesSubplot:title={'center':'Tiene un problema de baches?'}>

# %% [markdown]
# # estimacion_cantidad

# %%
df["estimacion_cantidad"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='estimacion_cantidad'>

# %% [markdown]
# # tipo_camino

# %%
df["tipo_camino"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='tipo_camino'>

# %% [markdown]
# # tiempo_reparaciones

# %%
df["tiempo_reparaciones"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='tiempo_reparaciones'>

# %% [markdown]
# # como_denunciar

# %%
df["como_denunciar"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='como_denunciar'>

# %% [markdown]
# # acceso_informacion

# %%
df["acceso_informacion"].value_counts(normalize=True).plot(kind="pie",
            explode=[0,.02,.3],
            title='Tiene acceso a la informacion.',
            legend=True,
            xlabel='',
            ylabel='')
# Out:
# <AxesSubplot:title={'center':'Tiene acceso a la informacion.'}>

# %% [markdown]
# # sufrio_accidentes

# %%
df["sufrio_accidentes"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sufrio_accidentes'>

# %% [markdown]
# # frecuencia_mantenimiento

# %%
df["frecuencia_mantenimiento"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='frecuencia_mantenimiento'>

# %% [markdown]
# # denunciaria_baches

# %%
df["denunciaria_baches"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='denunciaria_baches'>

# %% [markdown]
# # util_conocer

# %%
df["util_conocer"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='util_conocer'>

# %% [markdown]
# # respuesta_gubernamental

# %%
df["respuesta_gubernamental"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='respuesta_gubernamental'>

# %% [markdown]
# # regularidad_reparaciones

# %%
df["regularidad_reparaciones"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='regularidad_reparaciones'>
