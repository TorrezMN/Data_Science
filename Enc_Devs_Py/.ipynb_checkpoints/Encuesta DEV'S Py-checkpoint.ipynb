# %% [markdown]
# # ENCUESTA DEVS - PY 2021

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    # Importing Libs
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [10, 5]

# %%
df = pd.read_csv('enc_devs_py.csv')

# %% [markdown]
# ### Inspeccion inicial del dataset.

# %%
for i in df.columns:
    print(i)
# Out:
# Marca temporal
# Modalidad
# Trabajo
# Tipo de trabajo
# DevOps
# Codificar por trabajo
# Experiencia en TI
# Experiencia en codificación
# Primera línea de código en una máquina
# Educación
# Carreras o especialidades
# Importancia educación formal
# Género
# Edad actual
# Salario mensual
# Programación, scripting y lenguajes de marcado
# Librerías o web frameworks
# Otras frameworks, librerías y herramientas
# Base de datos
# Plataformas
# Lenguaje favorito
# Lenguaje más odiado
# Framework favorito
# Framework más odiado
# Herramientas

# %%
df.shape
# Out:
# (342, 25)

# %% [markdown]
# - Contamos con un df de 342 filas y 25 columnas.

# %% [markdown]
# ### Diccionario de datos.

# %% [markdown]
# - Modalidad : Tipo de trabajo que realiza. Presencial / Remoto / Hibrido.
# - Trabajo: Nacional o extranjeros.
# - Tipo de trabajo: Rol del trabajo que realiza. Dev/Designer
# - DevOps: Rol del trabajo en DEVOPS.
# - Codificar por trabajo: Su trabajo requiere programacion?
# - Experiencia en TI: Años trabajando en TI.
# - Experiencia en codificación: Años de experiencia en codificacion.
# - Primera línea de código en una máquina: Edad en la que realizo la primera linea de codigo.
# - Educación: Tipo de educacion recibida.
# - Carreras o especialidades: Carrera o especializacion.
# - Importancia educación formal: Considera que la educacion formal es importante?
# - Género : Sexo de la persona que responde.
# - Edad actual : Edad actual al momento de responder la pregunta.
# - Salario mensual : Salario mensual persivido.
# - Programación, scripting y lenguajes de marcado: Lenguajes de programacion usados.
# - Librerías o web frameworks: Librerias uilizadas.
# - Otras frameworks, librerías y herramientas: Otras librerias utilizadas.
# - Base de datos: Bases de datos utilizadas.
# - Plataformas: Plataformas de trabajo.
# - Lenguaje favorito: Lenguaje favorito.
# - Lenguaje más odiado: Lenguaje mas odiado.
# - Framework favorito: Framework favorito.
# - Framework más odiado: Framework mas odiado.
# - Herramientas: Herramientas utilizadas para el desarrollo de sus actividades.

# %% [markdown]
# ---

# %% [markdown]
# ### Vamos a hacer algunas modificaciones.
#
#     - Lo que quiere decir que se van a revisar columna a columna los valores que contienen y realizar algunas modificaciones para poder manejarlos.
#     prestando especial atencion al tamaño de los textos, evitando que queden textos muy largos.

# %%
cols = [ i for i in df.columns]

# %%
""" Renombrando las columnas disponibles para poder remplazar los 
espacios en blanco y acortar los nombres."""

col_names = {i:i.replace(',','').replace(' ','_').lower() for i in cols}

# %%
col_names.values()
# Out:
# dict_values(['marca_temporal', 'modalidad', 'trabajo', 'tipo_de_trabajo', 'devops', 'codificar_por_trabajo', 'experiencia_en_ti', 'experiencia_en_codificación_', 'primera_línea_de_código_en_una_máquina', 'educación', 'carreras_o_especialidades', 'importancia_educación_formal', 'género', 'edad_actual_', 'salario_mensual', 'programación_scripting_y_lenguajes_de_marcado', 'librerías_o_web_frameworks', 'otras_frameworks_librerías_y_herramientas', 'base_de_datos', 'plataformas', 'lenguaje_favorito', 'lenguaje_más_odiado', 'framework_favorito', 'framework_más_odiado', 'herramientas'])

# %%
df.rename(columns = col_names, inplace=True)

# %%
df.columns
# Out:
# Index(['marca_temporal', 'modalidad', 'trabajo', 'tipo_de_trabajo', 'devops',
#        'codificar_por_trabajo', 'experiencia_en_ti',
#        'experiencia_en_codificación_',
#        'primera_línea_de_código_en_una_máquina', 'educación',
#        'carreras_o_especialidades', 'importancia_educación_formal', 'género',
#        'edad_actual_', 'salario_mensual',
#        'programación_scripting_y_lenguajes_de_marcado',
#        'librerías_o_web_frameworks',
#        'otras_frameworks_librerías_y_herramientas', 'base_de_datos',
#        'plataformas', 'lenguaje_favorito', 'lenguaje_más_odiado',
#        'framework_favorito', 'framework_más_odiado', 'herramientas'],
#       dtype='object')

# %%
df.head()
# Out:
#                    marca_temporal modalidad              trabajo  \
# 0  2021/03/01 5:56:11 p. m. GMT-3    Remoto  Nacional (Paraguay)
# 1  2021/03/01 5:57:32 p. m. GMT-3   Hibrído  Nacional (Paraguay)
# 2  2021/03/01 5:57:57 p. m. GMT-3   Hibrído  Nacional (Paraguay)
# 3  2021/03/01 5:59:04 p. m. GMT-3   Hibrído                Ambas
# 4  2021/03/01 5:59:44 p. m. GMT-3    Remoto  Nacional (Paraguay)
#
#                                      tipo_de_trabajo  \
# 0                                       QA o testing
# 1  Desarrollador full-stack;Aplicaciones de escri...
# 2                            Desarrollador front-end
# 3                           Desarrollador full-stack
# 4                               Desarrollador mobile
#
#                                devops codificar_por_trabajo experiencia_en_ti  \
# 0                            Educador                    No   Menos de 5 años
# 1  Administrador de sistemas;Educador                    Sí      15 a 19 años
# ...

# %% [markdown]
# ### Modalidad

# %%
df['modalidad'].replace({
    'Ninguna de las anteriores': 'Ninguna',
}, regex=True, inplace=True)

# %%
df.modalidad.value_counts()
# Out:
# Remoto        145
# Hibrído       110
# Presencial     78
# Ninguna         9
# Name: modalidad, dtype: int64

# %% [markdown]
# ### Trabajo

# %%
df['trabajo'].value_counts()
# Out:
# Nacional (Paraguay)    259
# Ambas                   44
# Internacional           39
# Name: trabajo, dtype: int64

# %% [markdown]
# ### Tipo de Trabajo

# %%
df['tipo_de_trabajo'].value_counts()
# Out:
# Desarrollador full-stack                                                                                                                                                                                             55
# Desarrollador back-end                                                                                                                                                                                               29
# Desarrollador front-end                                                                                                                                                                                              16
# Aplicaciones de escritorio o empresariales                                                                                                                                                                           15
# ...

# %%
df['tipo_de_trabajo'].replace({
    'Desarrollador':'Dev',
    'Project Leader':'Project Lead',
    'Aplicaciones':'Aps',
    'Administrador de base de datos':'DB Admin',
    
},regex=True, inplace=True)

# %%
for i in df['tipo_de_trabajo'].value_counts().keys():
    for j in i.split(';'):
        print(j)
# Out:
# Dev full-stack
# Dev back-end
# Dev front-end
# Aps de escritorio o empresariales
# Dev back-end
# Dev front-end
# Project Lead
# Dev back-end
# Dev front-end
# Dev full-stack
# Dev mobile
# QA o testing
# Dev full-stack
# Project Lead
# DB Admin
# Dev full-stack
# Dev mobile
# Dev full-stack
# Aps de escritorio o empresariales
# DB Admin
# Dev back-end
# Dev full-stack
# Dev back-end
# Dev front-end
# Dev full-stack
# Dev mobile
# Dev front-end
# Dev mobile
# Dev back-end
# Dev front-end
# DB Admin
# Dev full-stack
# Aps de escritorio o empresariales
# Dev back-end
# DB Admin
# Dev full-stack
# Aps de escritorio o empresariales
# Project Lead
# Dev back-end
# Dev front-end
# Dev mobile
# Dev back-end
# Aps de escritorio o empresariales
# Dev back-end
# Project Lead
# Dev back-end
# Dev front-end
# Dev full-stack
# DB Admin
# Dev back-end
# Dev front-end
# Dev full-stack
# QA o testing
# DB Admin
# Project Lead
# Dev de sistemas embebidos
# Aps de escritorio o empresariales
# ...

# %% [markdown]
# ### DevOps

# %%
for i in df.devops.value_counts().keys():
    for j in i.split(';'):
        print(j)
# Out:
# Administrador de sistemas
# Diseñador
# Científico de datos o especialista Machine Learning
# Educador
# Administrador de sistemas
# Diseñador
# Administrador de sistemas
# Educador
# Administrador de sistemas
# Investigador científico
# Administrador de sistemas
# Científico de datos o especialista Machine Learning
# Científico de datos o especialista Machine Learning
# Diseñador
# Diseñador
# Educador
# Administrador de sistemas
# Científico de datos o especialista Machine Learning
# Investigador científico
# Diseñador
# Investigador científico
# Investigador científico
# Diseñador
# Administrador de sistemas
# Científico de datos o especialista Machine Learning
# Investigador científico
# Investigador científico
# Educador
# Científico de datos o especialista Machine Learning
# Educador
# Administrador de sistemas
# Científico de datos o especialista Machine Learning
# Investigador científico
# Diseñador
# Educador
# Administrador de sistemas
# ...

# %%
df['devops'].replace({
    'Científico de datos o especialista Machine Learning':'Data Scientist ML Specialist',
    'Administrador de sistemas':'Sys Admin',
    'Investigador científico':'Inv. Cientifico',
}, regex=True, inplace = True)

# %%
df['devops'].value_counts()
# Out:
# Sys Admin                                                                    69
# Diseñador                                                                    20
# Data Scientist ML Specialist                                                  9
# Educador                                                                      8
# Sys Admin;Diseñador                                                           6
# Sys Admin;Educador                                                            5
# Sys Admin;Inv. Cientifico                                                     5
# Sys Admin;Data Scientist ML Specialist                                        4
# Data Scientist ML Specialist;Diseñador                                        2
# Diseñador;Educador                                                            2
# Sys Admin;Data Scientist ML Specialist;Inv. Cientifico                        2
# Inv. Cientifico;Diseñador                                                     2
# ...

# %% [markdown]
# ### 'codificar_por_trabajo'

# %%
df['codificar_por_trabajo'].value_counts()
# Out:
# Sí    317
# No     25
# Name: codificar_por_trabajo, dtype: int64

# %% [markdown]
# ### 'experiencia_en_ti'

# %%
df['experiencia_en_ti'].value_counts().keys()
# Out:
# Index(['5 a 9 años', 'Menos de 5 años', '10 a 14 años', '15 a 19 años',
#        '20 a 24 años', '25 a 29 años', '30 a 34 años', '35 a 39 años',
#        '45 a 49 años', 'más de 50 años'],
#       dtype='object')

# %%
df['experiencia_en_ti'].replace({
    "5 a 9 años":"5-9",
    "Menos de 5 años":"<5",
    "10 a 14 años":"10-14",
    "15 a 19 años":"15-19",
    "20 a 24 años":"20-24",
    "25 a 29 años":"25-29",
    "30 a 34 años":"30-34",
    "35 a 39 años":"35-39",
    "más de 50 años":">50",
    "45 a 49 años":"45-49",
},regex=True, inplace =True)

# %%
df['experiencia_en_ti'].value_counts()
# Out:
# 5-9      124
# <5        94
# 10-14     82
# 15-19     20
# 20-24      9
# 25-29      5
# 30-34      4
# 35-39      2
# 45-49      1
# >50        1
# Name: experiencia_en_ti, dtype: int64

# %% [markdown]
# ### 'experiencia_en_codificación_'

# %%
df['experiencia_en_codificación_'].value_counts().keys()
# Out:
# Index(['5 a 9 años', 'Menos de 5 años', '10 a 14 años', '15 a 19 años',
#        '20 a 24 años', '25 a 29 años', '30 a 34 años', '35 a 39 años'],
#       dtype='object')

# %%
df['experiencia_en_codificación_'].replace({
    "5 a 9 años":"5-9",
    "Menos de 5 años":"<5",
    "10 a 14 años":"10-14",
    "15 a 19 años":"15-19",
    "20 a 24 años":"20-24",
    "25 a 29 años":"25-29",
    "30 a 34 años":"30-34",
    "35 a 39 años":"35-39",
}, regex=True, inplace=True)

# %%
df['experiencia_en_codificación_'].value_counts()
# Out:
# 5-9      125
# <5       111
# 10-14     64
# 15-19     20
# 20-24      7
# 25-29      6
# 30-34      4
# 35-39      2
# Name: experiencia_en_codificación_, dtype: int64

# %% [markdown]
# ### 'primera_línea_de_código_en_una_máquina'

# %%
df['primera_línea_de_código_en_una_máquina'].value_counts().keys()
# Out:
# Index(['Menos de 10 años', '10 a 11 años', '14 a 15 años', '12 a 13 años',
#        '16 a 17 años', '18 a 19 años', '20 a 21 años', 'más de 30 años',
#        '22 a 23 años', '26 a 27 años', '28 a 29 años', '24 a 25 años'],
#       dtype='object')

# %%
df['primera_línea_de_código_en_una_máquina'].replace({
    'Menos de 10 años': '<10',
    '10 a 11 años':'10-11', 
    '14 a 15 años':'14-15', 
    '12 a 13 años':'12-13',
    '16 a 17 años':'16-17', 
    '18 a 19 años':'18-19', 
    '20 a 21 años':'20-21', 
    'más de 30 años':'>30',
    '26 a 27 años':'26-27', 
    '22 a 23 años':'22-23', 
    '24 a 25 años':'24-25', 
    '28 a 29 años':'28-29',
},regex=True, inplace=True)

# %%
df['primera_línea_de_código_en_una_máquina'].value_counts()
# Out:
# <10      101
# 10-11     55
# 14-15     51
# 12-13     37
# 16-17     31
# 18-19     27
# 20-21     16
# >30        6
# 22-23      4
# 26-27      4
# 28-29      3
# 24-25      3
# Name: primera_línea_de_código_en_una_máquina, dtype: int64

# %% [markdown]
# ### 'educación'

# %%
cats =[]
for i in df['educación'].value_counts().keys():
    for j in i.split(';'):
        if(j not in cats):
            cats.append(j)

# %%
cats
# Out:
# ['Educación universitaria',
#  'Educación básica',
#  'Educación secundaria',
#  'Autodidacta',
#  'Master',
#  'Doctorado']

# %%
df['educación'].replace({
    'Educación universitaria':'Ed. Universitaria',
    'Educación básica': 'Ed. Basica',
    'Educación secundaria': 'Ed. Secundaria',
    'Autodidacta': 'Autodidacta',
},regex=True, inplace=True)

# %%
df['educación'].value_counts()
# Out:
# Ed. Universitaria                                                           151
# Ed. Basica;Ed. Secundaria;Ed. Universitaria                                  42
# Ed. Basica;Ed. Secundaria;Ed. Universitaria;Autodidacta                      36
# Ed. Universitaria;Autodidacta                                                29
# Master                                                                       17
# Ed. Secundaria                                                               12
# Ed. Basica;Ed. Secundaria                                                    11
# Ed. Basica;Ed. Secundaria;Autodidacta                                        10
# Ed. Secundaria;Autodidacta                                                    8
# Ed. Universitaria;Master                                                      8
# Ed. Basica;Ed. Secundaria;Ed. Universitaria;Master                            4
# Ed. Universitaria;Master;Autodidacta                                          3
# ...

# %% [markdown]
# ### 'carreras_o_especialidades'

# %%
df['carreras_o_especialidades'].value_counts().keys()
# Out:
# Index(['Ingeniero Informática', 'Análisis de sistemas',
#        'Programación;Análisis de sistemas',
#        'Programación;Ingeniero Informática',
#        'Programación;Análisis de sistemas;Ingeniero Informática',
#        'Programación', 'Ninguna', 'Análisis de sistemas;Ingeniero Informática',
#        'Ingeniero Electrónica', 'Programación;Análisis de sistemas;Otras',
#        'Otras', 'Ingeniero Informática;Otras', 'Otras ingenerías',
#        'Programación;Análisis de sistemas;Diseño gráfico',
#        'Análisis de sistemas;Otras', 'Programación;Otras',
#        'Programación;Ingeniero Informática;Otras',
#        'Programación;Diseño gráfico',
#        'Programación;Análisis de sistemas;Ingeniero Informática;Otras',
#        'Programación;Diseño gráfico;Otras', 'Diseño gráfico',
#        'Programación;Análisis de sistemas;Ingeniero Informática;Diseño gráfico;Otras',
#        'Análisis de sistemas;Ingeniero Electrónica',
# ...

# %%
esp = []
for i in df['carreras_o_especialidades'].value_counts().keys():
    for j in i.split(';'):
        if (j not in esp):
            esp.append(j)

# %%
esp
# Out:
# ['Ingeniero Informática',
#  'Análisis de sistemas',
#  'Programación',
#  'Ninguna',
#  'Ingeniero Electrónica',
#  'Otras',
#  'Otras ingenerías',
#  'Diseño gráfico',
#  'Matemático',
#  'Ingeniero Civil']

# %%
df['carreras_o_especialidades'].replace({
    'Ingeniero Informática': 'Ing. Informática',
    'Análisis de sistemas':'Análisis de Sistemas',
    'Ingeniero Electrónica':'Ing. Electrónica',
    'Otras ingenerías':'Otras Ing.',
    'Diseño gráfico':'Diseño Gráfico',
    'Ingeniero Civil':'Ing. Civil',
},regex=True, inplace=True)

# %%
df['carreras_o_especialidades'].value_counts()
# Out:
# Ing. Informática                                                           107
# Análisis de Sistemas                                                        69
# Programación;Análisis de Sistemas                                           33
# Programación;Ing. Informática                                               21
# Programación;Análisis de Sistemas;Ing. Informática                          17
# Programación                                                                17
# Ninguna                                                                     15
# Análisis de Sistemas;Ing. Informática                                       11
# Ing. Electrónica                                                             6
# Otras                                                                        5
# Programación;Análisis de Sistemas;Otras                                      5
# Otras Ing.                                                                   4
# ...

# %% [markdown]
# ### 'importancia_educación_formal'

# %%
df['importancia_educación_formal' ].value_counts().keys()
# Out:
# Index(['Más o menos importante', 'Bastante importante', 'Muy importante',
#        'No importa, no es necesario', 'Crítico'],
#       dtype='object')

# %%
df['importancia_educación_formal' ].replace({
    'Más o menos importante': '+ || -',
    'Bastante importante':'BASTANTE', 
    'Muy importante':'MUY',
    'No importa, no es necesario':'NO', 
    'Crítico':'CRITICO',
},regex=True, inplace=True)

# %%
df['importancia_educación_formal' ].value_counts().keys()
# Out:
# Index(['+ || -', 'BASTANTE', 'MUY', 'NO', 'CRITICO'], dtype='object')

# %% [markdown]
# ### 'género'

# %%
df['género'].value_counts().keys()
# Out:
# Index(['Hombre', 'Mujer', 'Prefiero no compartir', 'Otros', 'Género'], dtype='object')

# %%
# AGRUPAR GENEROS POR MINORIAS. 
# Se de antemano que las categorias 'Prefiero no compartir', 'Otros' y 'Género' 
# tienen valores muy reducidos y no representan un numero relevante.
# Por esta razon las voy a agrupar en una sola categoria 'NO COMPARTO'.

# %%
df['género'].replace({
    'Hombre':'HOMBRE', 
    'Mujer':'MUJER',
    'Prefiero no compartir':'NO COMPARTO', 
    'Otros':'NO COMPARTO', 
    'Género':'NO COMPARTO',
}, regex=True, inplace=True)

# %%
df['género'].value_counts()
# Out:
# HOMBRE         279
# MUJER           49
# NO COMPARTO      6
# Name: género, dtype: int64

# %% [markdown]
# ### 'edad_actual_'

# %%
df['edad_actual_'].value_counts().keys()
# Out:
# Index(['30 a 34 años', '25 a 29 años', '35 a 39 años', '20 a 24 años',
#        '40 a 44 años', '15 a 19 años', '45 a 49 años', '50 a 54 años',
#        '55 a 59 años'],
#       dtype='object')

# %%
df['edad_actual_' ].replace({
    '30 a 34 años': '30-34', 
    '25 a 29 años':'25-29', 
    '35 a 39 años':'35-39', 
    '20 a 24 años':'20-24', 
    '40 a 44 años':'40-44',  
    '15 a 19 años':'15-19',  
    '50 a 54 años':'50-54',  
    '55 a 59 años':'55-59', 
    '45 a 49 años':'45-49', 
}, regex=True, inplace=True)

# %%
df['edad_actual_' ].value_counts()
# Out:
# 30-34    120
# 25-29     98
# 35-39     51
# 20-24     42
# 40-44     16
# 15-19      6
# 45-49      3
# 55-59      3
# 50-54      3
# Name: edad_actual_, dtype: int64

# %% [markdown]
# ### 'salario_mensual'

# %%
df['salario_mensual'].value_counts().keys()
# Out:
# Index(['Entre 5.000.000 a 7.000.000 gs', 'Entre 7.000.000 a 9.000.000 gs',
#        'Entre 3.500.000 a 5.000.000 gs', 'Entre 9.000.000 a 12.000.000 gs',
#        'Entre 2.192.839 gs a 3.500.000 gs', 'Entre 12.000.000 a 15.000.000 gs',
#        'Más de 27.000.000 gs', 'Entre 15.000.000 a 18.000.000 gs',
#        'Menos del salario mínimo ( 2.192.839 gs)',
#        'Entre 18.000.000 a 21.000.000 gs', 'Salario mínimo 2.192.839 gs',
#        'Entre 21.000.000 a 24.000.000 gs', 'Entre 24.000.000 a 27.000.000 gs'],
#       dtype='object')

# %%
df["salario_mensual"].replace({
    "Entre 5.000.000 a 7.000.000 gs":"5.000.000 a 7.000.000 Gs.",
    "Entre 7.000.000 a 9.000.000 gs":"7.000.000 a 9.000.000 Gs.",
    "Entre 3.500.000 a 5.000.000 gs":"3.500.000 a 5.000.000 Gs.",
    "Entre 9.000.000 a 12.000.000 gs":"9.000.000 a 12.000.000 Gs.",
    "Entre 2.192.839 gs a 3.500.000 gs":"2.192.839 gs a 3.500.000 Gs.",
    "Entre 12.000.000 a 15.000.000 gs":"12.000.000 a 15.000.000 Gs.",
    "Más de 27.000.000 gs":"> 27.000.000 Gs.",
    "Entre 15.000.000 a 18.000.000 gs":"15.000.000 a 18.000.000 Gs.",
    "Menos del salario mínimo ( 2.192.839 gs)":"< 2.192.839 Gs.",
    "Entre 18.000.000 a 21.000.000 gs":"18.000.000 a 21.000.000 Gs.",
    "Salario mínimo 2.192.839 gs":"2.192.839 Gs.",
    "Entre 21.000.000 a 24.000.000 gs":"21.000.000 a 24.000.000 Gs.",
    "Entre 24.000.000 a 27.000.000 gs":"24.000.000 a 27.000.000 Gs.",
}, inplace=True)

# %%
df['salario_mensual'].value_counts()
# Out:
# 5.000.000 a 7.000.000 Gs.       62
# 7.000.000 a 9.000.000 Gs.       50
# 3.500.000 a 5.000.000 Gs.       46
# 9.000.000 a 12.000.000 Gs.      45
# 2.192.839 gs a 3.500.000 Gs.    39
# 12.000.000 a 15.000.000 Gs.     28
# > 27.000.000 Gs.                17
# 15.000.000 a 18.000.000 Gs.     14
# < 2.192.839 Gs.                 13
# 18.000.000 a 21.000.000 Gs.      9
# 2.192.839 Gs.                    8
# 21.000.000 a 24.000.000 Gs.      7
# 24.000.000 a 27.000.000 Gs.      4
# Name: salario_mensual, dtype: int64

# %% [markdown]
# ### 'programación_scripting_y_lenguajes_de_marcado'

# %%
df['programación_scripting_y_lenguajes_de_marcado'].value_counts()
# Out:
# JavaScript;PHP;HTML/CSS;SQL                                                10
# JavaScript;TypeScript;Python;Java;HTML/CSS;SQL                              5
# JavaScript;PHP;HTML/CSS;SQL;Bash/Shell/PowerShell                           5
# JavaScript;TypeScript;Java;HTML/CSS;SQL                                     5
# JavaScript;Java;HTML/CSS;SQL                                                4
#                                                                            ..
# Java;HTML/CSS;SQL                                                           1
# JavaScript;PHP;Java;HTML/CSS;Bash/Shell/PowerShell                          1
# JavaScript;TypeScript;PHP;Python;Java;C;HTML/CSS;SQL;Swift                  1
# JavaScript;PHP;Python;Java;C#;HTML/CSS;SQL;Bash/Shell/PowerShell;R;Perl     1
# JavaScript;TypeScript;PHP;C;C#;HTML/CSS;SQL                                 1
# Name: programación_scripting_y_lenguajes_de_marcado, Length: 270, dtype: int64

# %%
for i in df['programación_scripting_y_lenguajes_de_marcado'].value_counts().keys():
    for j in i.split(';'):
        print(j)
# Out:
# JavaScript
# PHP
# HTML/CSS
# SQL
# JavaScript
# TypeScript
# Python
# Java
# HTML/CSS
# SQL
# JavaScript
# PHP
# HTML/CSS
# SQL
# Bash/Shell/PowerShell
# JavaScript
# TypeScript
# Java
# HTML/CSS
# SQL
# JavaScript
# Java
# HTML/CSS
# SQL
# JavaScript
# HTML/CSS
# JavaScript
# TypeScript
# PHP
# Python
# Java
# HTML/CSS
# SQL
# Bash/Shell/PowerShell
# Python
# SQL
# Java
# JavaScript
# PHP
# Java
# SQL
# SQL
# SQL
# Oracle form
# Java
# SQL
# JavaScript
# C#
# HTML/CSS
# SQL
# JavaScript
# Python
# C#
# HTML/CSS
# SQL
# JavaScript
# PHP
# HTML/CSS
# JavaScript
# TypeScript
# Python
# HTML/CSS
# SQL
# JavaScript
# TypeScript
# PHP
# Python
# HTML/CSS
# SQL
# Java
# C#
# SQL
# JavaScript
# TypeScript
# Python
# Java
# HTML/CSS
# SQL
# Bash/Shell/PowerShell
# JavaScript
# C#
# SQL
# JavaScript
# TypeScript
# Python
# Java
# Go
# HTML/CSS
# SQL
# Bash/Shell/PowerShell
# Oracle form
# C#
# SQL
# JavaScript
# PHP
# Python
# HTML/CSS
# SQL
# JavaScript
# PHP
# Java
# HTML/CSS
# SQL
# ...

# %% [markdown]
# ### 'librerías_o_web_frameworks'

# %%
df['librerías_o_web_frameworks'].value_counts().keys()
# Out:
# Index(['JQuery', 'Spring', 'ASP.NET;ASP.NET Core', 'JQuery;Laravel',
#        'React.js', 'JQuery;ASP.NET;Spring', 'JQuery;Vue.js;Laravel',
#        'Angular;Angular.js;JQuery;Spring', 'React.js;Express', 'JQuery;Django',
#        ...
#        'React.js;JQuery;Express;Django;Flask;Laravel',
#        'React.js;JQuery;Express;CodeIgniter;Ruby on Rails',
#        'React.js;Angular;JQuery;Laravel;Ruby on Rails',
#        'React.js;JQuery;ASP.NET;ASP.NET Core', 'Express;Django',
#        'React.js;JQuery;Spring;Django;Flask',
#        'React.js;JQuery;Laravel;Symfony;CodeIgniter',
#        'React.js;Angular.js;JQuery;Express;Django;Flask;Ruby on Rails',
#        'Angular;Angular.js;JQuery;Express;Spring;Django',
#        'React.js;Angular;Angular.js;JQuery;Spring;Django;Flask'],
#       dtype='object', length=201)

# %% [markdown]
# ### 'otras_frameworks_librerías_y_herramientas'

# %%
df['otras_frameworks_librerías_y_herramientas' ].value_counts().keys()
# Out:
# Index(['Node.js', '.NET', '.NET;NET Core', 'Node.js;React Native',
#        'Node.js;Flutter', 'Node.js;.NET', 'Flutter', 'Node.js;.NET;NET Core',
#        'Node.js;Cordova', 'React Native', 'Cordova', 'Node.js;.NET;Flutter',
#        'Node.js;Pandas', '.NET;Xamarin', 'Pandas;TensorFlow;Keras',
#        'Node.js;Pandas;TensorFlow', 'Pandas', 'Node.js;React Native;Cordova',
#        'Flutter;Xamarin',
#        'Node.js;Pandas;TensorFlow;React Native;Keras;Torch/PyTorch',
#        'Node.js;Keras;Hadoop', 'Ansible', 'Node.js;Pandas;Cordova',
#        'Node.js;React Native;Flutter', 'Node.js;.NET;React Native',
#        'Node.js;React Native;Unity 3D;Flutter',
#        'Node.js;Pandas;TensorFlow;React Native;Unity 3D;Flutter;Unreal Engine',
#        'Pandas;Keras', 'Node.js;.NET;React Native;Flutter;Xamarin',
#        'React Native;Ansible;Flutter;Puppet;Chef', 'Node.js;Flutter;Cordova',
#        'Pandas;Flutter', 'NET Core;Hadoop', 'Pandas;Xamarin',
# ...

# %% [markdown]
# ### 'base_de_datos'

# %%
df['base_de_datos'].value_counts().keys()
# Out:
# Index(['PostgreSQL', 'MySQL;PostgreSQL;Oracle',
#        'MySQL;PostgreSQL;Microsoft SQL Server', 'MySQL;PostgreSQL',
#        'MySQL;MariaDB', 'PostgreSQL;Oracle',
#        'MySQL;PostgreSQL;Microsoft SQL Server;Oracle', 'Microsoft SQL Server',
#        'MySQL;MariaDB;PostgreSQL',
#        'MySQL;MariaDB;PostgreSQL;Microsoft SQL Server',
#        ...
#        'MySQL;MariaDB;PostgreSQL;Microsoft SQL Server;MongoDB;Oracle;Cassandra;IBM DB2',
#        'MySQL;MariaDB;PostgreSQL;Microsoft SQL Server;SQLite;MongoDB;Oracle;Firebase;Elasticsearch',
#        'MySQL;MariaDB;PostgreSQL;Microsoft SQL Server;MongoDB;Redis;Oracle',
#        'PostgreSQL;Microsoft SQL Server;Oracle;Cassandra',
#        'MySQL;MariaDB;PostgreSQL;SQLite;MongoDB;Redis;Elasticsearch',
#        'MySQL;PostgreSQL;IBM DB2',
#        'MySQL;MariaDB;PostgreSQL;Oracle;Elasticsearch',
#        'MySQL;MariaDB;PostgreSQL;Microsoft SQL Server;MongoDB;Firebase',
# ...

# %% [markdown]
# ### 'plataformas'

# %%
df['plataformas' ].value_counts().keys()
# Out:
# Index(['GNU/Linux;Microsoft Windows', 'Microsoft Windows', 'GNU/Linux',
#        'GNU/Linux;Microsoft Windows;Docker',
#        'GNU/Linux;Microsoft Windows;Android',
#        'GNU/Linux;Microsoft Windows;MacOS', 'GNU/Linux;MacOS',
#        'Microsoft Windows;Android', 'GNU/Linux;Microsoft Windows;Docker;AWS',
#        'Microsoft Windows;MacOS',
#        ...
#        'GNU/Linux;Microsoft Windows;Docker;Android;Raspberry Pi;Google Cloud Platform;Kubernetes;Arduino',
#        'GNU/Linux;Microsoft Windows;MacOS;AWS;Android;iOS',
#        'GNU/Linux;Microsoft Windows;MacOS;Docker;AWS;Android;WordPress;Heroku',
#        'GNU/Linux;Microsoft Windows;Android;Arduino', 'MacOS;AWS;Android;iOS',
#        'GNU/Linux;Docker;AWS;Raspberry Pi;Microsoft Azure;WordPress;Google Cloud Platform;Kubernetes;Arduino',
#        'GNU/Linux;MacOS;Docker;AWS;WordPress',
#        'GNU/Linux;Microsoft Windows;AWS;Heroku', 'GNU/Linux;Docker;AWS',
#        'GNU/Linux;MacOS;Docker;AWS;Android'],
# ...

# %% [markdown]
# ### 'lenguaje_favorito'

# %%
df['lenguaje_favorito' ].value_counts().keys()
# Out:
# Index(['Java', 'Python', 'JavaScript', 'PHP', 'C#', 'SQL', 'TypeScript',
#        'HTML/CSS', 'Oracle form', 'Genexus', 'Kotlin', 'C++', 'Otro', 'Ruby',
#        'Go', 'Dart', 'C', 'Swift', 'VBA', 'Rust', 'COBOL',
#        'Bash/Shell/PowerShell', 'OpcióFox Pron 27'],
#       dtype='object')

# %% [markdown]
# ### 'lenguaje_más_odiado'

# %%
df['lenguaje_más_odiado'].value_counts().keys()
# Out:
# Index(['Java', 'PHP', 'JavaScript', 'Genexus', 'Fox Pro', 'C', 'C++',
#        'Assembly', 'VBA', 'COBOL', 'HTML/CSS', 'Ruby', 'Oracle form',
#        'Bash/Shell/PowerShell', 'Objective-C', 'SQL', 'RPG', 'C#', 'Haskell',
#        'R', 'Perl', 'TypeScript', 'Spring', 'Go', 'Kotlin', 'Python', 'Swift'],
#       dtype='object')

# %% [markdown]
# ### 'framework_favorito'

# %%
df['framework_favorito' ].value_counts().keys()
# Out:
# Index(['React.js', 'Laravel', 'Spring', 'Django', 'Angular', 'Vue.js',
#        'ASP.NET', 'Express', 'ASP.NET Core', 'JQuery', 'Ruby on Rails',
#        'Angular.js', 'Flask', 'CakePHP', 'CodeIgniter'],
#       dtype='object')

# %% [markdown]
# ### 'framework_más_odiado'

# %%
df['framework_más_odiado' ].value_counts().keys()
# Out:
# Index(['JQuery', 'Spring', 'ASP.NET', 'Angular', 'Laravel', 'Angular.js',
#        'React.js', 'Ruby on Rails', 'CakePHP', 'ASP.NET Core', 'CodeIgniter',
#        'Django', 'Express', 'Vue.js', 'Flask', 'Gastby'],
#       dtype='object')

# %% [markdown]
# ### 'herramientas'

# %%
df['herramientas'].value_counts().keys()
# Out:
# Index(['GitHub;GitLab',
#        'GitHub;Slack;GitLab;Google Suite (Docs, Meet, etc);Trello',
#        'GitHub;Slack;GitLab;Jira;Google Suite (Docs, Meet, etc);Confluence',
#        'GitHub;Slack;GitLab;Jira;Google Suite (Docs, Meet, etc);Confluence;Microsoft Team;Trello',
#        'GitHub;Slack;GitLab;Google Suite (Docs, Meet, etc);Trello;Discord',
#        'GitHub;GitLab;Google Suite (Docs, Meet, etc)',
#        'GitHub;GitLab;Google Suite (Docs, Meet, etc);Trello', 'GitHub',
#        'Microsoft Team',
#        'GitHub;Slack;GitLab;Jira;Google Suite (Docs, Meet, etc);Trello',
#        ...
#        'GitHub;Slack;GitLab;Trello',
#        'GitHub;Slack;Google Suite (Docs, Meet, etc);Microsoft Team;Microsoft Azure',
#        'GitHub;GitLab;Jira;Confluence',
#        'GitHub;Slack;GitLab;Google Suite (Docs, Meet, etc);Confluence;Microsoft Team;Trello',
#        'GitHub;Jira;Google Suite (Docs, Meet, etc);Microsoft Team',
# ...

# %%
tools = []
for i in df['herramientas'].value_counts().keys():
    for j in i.split(';'):
        tools.append(j)

# %%
def replace_google(row):
    if('Google Suite (Docs, Meet, etc)' in str(row)):
        return(row.replace('Google Suite (Docs, Meet, etc)', 'Google Suite'))
    else:
        return(row)

# %%
df['herramientas'] = df['herramientas'].map(replace_google)

# %%
df['herramientas'].value_counts().keys()
# Out:
# Index(['GitHub;Slack;GitLab;Google Suite;Trello', 'GitHub;GitLab',
#        'GitHub;Slack;GitLab;Jira;Google Suite;Confluence;Microsoft Team;Trello',
#        'GitHub;Slack;GitLab;Jira;Google Suite;Confluence',
#        'GitHub;Slack;GitLab;Google Suite;Trello;Discord',
#        'GitHub;Slack;GitLab;Jira;Google Suite;Microsoft Team;Trello',
#        'GitHub;GitLab;Google Suite',
#        'GitHub;Slack;GitLab;Jira;Google Suite;Trello', 'Microsoft Team',
#        'GitHub;GitLab;Google Suite;Trello',
#        ...
#        'Slack;Google Suite',
#        'GitHub;GitLab;Jira;Google Suite;Confluence;Microsoft Team;Trello',
#        'GitHub;GitLab;Microsoft Team',
#        'GitHub;Slack;Jira;Microsoft Team;Discord',
#        'GitHub;GitLab;Jira;Trello;Discord', 'GitHub;Slack;GitLab;Trello',
#        'GitHub;GitLab;Jira;Confluence',
#        'GitHub;GitLab;Jira;Google Suite;Microsoft Team',
#        'Slack;Google Suite;Microsoft Team;Trello',
#        'GitHub;Google Suite;Trello'],
# ...

# %%
# Exportamos el DataSet arreglado.
df.to_csv('enc_devs_py_2021_fixed.csv', index=False)
